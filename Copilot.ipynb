# %%
# start spark session 
print('starting session, consider adjusting the session timeout')
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 4, Finished, Available, Finished)
# starting session

# %% [markdown]
# #### Run the cell below to install the required packages for Copilot
#
# (this cell will be automatically added to the top of any notebook where you enable the copilot button)

# %%
# None of this should be needed anymore given improvements to Fabric Copilot
#Run this cell to install the required packages for Copilot
# %pip install https://aka.ms/chat-magics-0.0.0-py3-none-any.whl
# %load_ext chat_magics

# %% [markdown]
# ## Fabric Copilot Notes
#
# * [How to Setup Fabric Copilot](https://blog.fabric.microsoft.com/en-US/blog/fabric-change-the-game-how-easy-is-it-to-use-copilot-in-microsoft-fabric/)
# * [How to ENABLE Fabric Copilot](https://blog.fabric.microsoft.com/en-US/blog/how-to-enable-copilot-in-fabric-for-everyone-2/): you must be a tenant admin
# * [Here is some additional information if you are having problems with the setup](https://www.serverlesssql.com/using-copilot-in-fabric-notebooks-for-data-engineering/)
#
# 1. Open a new Notebook and ensure you've added a lakehouse on the left
# 2. Copilot should be available as a button on the top right of the navbar.  Click it.  You should get a little explanatory window on the right side.
# 3. It should add a new cell with the necessary `chat_magics` setup process.  Run that code.  [Link to information on Chat-Magics](https://learn.microsoft.com/en-us/fabric/get-started/copilot-notebooks-chat-magics)

# %%
# %chat_magics
# This shows the help screen, but may not be needed anymore
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 7, Finished, Available, Finished)

# %% [markdown]
# This is a cell-level `chat-magic`.  Simply use natural language to chat with the data.

# %%
# %%chat
# What variables are currently defined?
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 8, Finished, Available, Finished)
# <details>
#     <summary>Reasoning</summary>
# Since this is a new notebook session, there might not be any predefined variables yet. However, I can list the currently available Lakehouse tables which can be used to identify data resources available for data science tasks.
# </details>
#
# I will list the available Lakehouse tables in the default lakehouse (davelake).
#
# Let's start by listing the tables in the default Lakehouse.
#
# <details>
#     <summary>Reasoning</summary>
# I have listed the tables available in the default lakehouse (davelake). These tables contain various schemas and columns which can be used for different data analysis tasks.
# </details>
#
# Here are the tables currently defined in the default Lakehouse (davelake):
#
# 1. davelake.dbo.philly_assessments
# 2. davelake.dbo.tempbl
# 3. davelake.dbo.philly_case_investigations
# 4. davelake.dbo.philly_business_licenses
# 5. davelake.dbo.philly_flattened_properties
# 6. davelake.dbo.philly_com_act_licenses
# 7. davelake.dbo.EntityAddressList
# 8. davelake.dbo.philly_demolitions
# 9. davelake.dbo.philly_real_estate_tax_balances
# 10. davelake.dbo.philly_appeals
# 11. davelake.dbo.philly_rtt_summary
# 12. davelake.dbo.philly_permits
# 13. davelake.dbo.philly_problempropertylist
# 14. davelake.dbo.masterentity
# 15. davelake.dbo.philly_opa_properties_public_pde
# 16. davelake.dbo.philly_violations
# 17. davelake.dbo.masterentityaddress
# 18. davelake.dbo.masteraddress
#
# You can explore the schema of any of these tables to identify the variables (columns) they contain. Let me know if you need further details about any specific table(s).

# %%
# %%chat
# # in the copilot pane or here...
# schema for davelake.dbo.masterentity
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 10, Finished, Available, Finished)
# <details>
#     <summary>Reasoning</summary>
# I have fetched the schema for the table `davelake.dbo.masterentity`. It consists of two columns: `MasterEntityId` and `NameText`.
# </details>
#
# Here is the schema for the table `davelake.dbo.masterentity` in the default lakehouse (davelake):
#
# - `MasterEntityId` (varchar): Contains unique identifiers for master entities. Example values include:
#   - dc75bb84-5ed7-4f2a-840b-924f0d09d719
#   - e90ff9af-1081-41ea-993f-dd37dbcdda92
#   - b3865c22-b9ba-4bdf-9ce1-37d7cf4f0550
# - `NameText` (varchar): Contains the names associated with the master entities. Example values include:
#   - SHAFIA GEORGIA
#   - SHAFIA HASS
#   - AMOS MONET
#   - BAH MONET AMOS
#   - ANDREWS DELAINE
#   - ANDREWS DELOREAN

# %% [markdown]
# `%%code` is used to have Copilot actually write code for you. You can also do this with the `Copilot` window that should be open on the right side of the screen.

# %%
# %%code
# In the bronze/theaters folder, Load Theatres.csv into a spark dataframe
# Out:
# **chat-magics** generated the following cell.  Tokens: 46
#
# Remember that AI can make mistakes, so carefully review code before executing.

# %%
#### ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

# Load the CSV into a Spark DataFrame
# file_path = '/lakehouse/default/Files/bronze/theaters/Theatres.csv'

# Note that it gets the file_path wrong above.  We had to fix it.  
file_path = 'Files/bronze/theaters/Theatres.csv'

spark_df = spark.read.format("csv").option("header", "true").load(file_path)

# Display the Spark DataFrame (optional)
spark_df.show()
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 22, Finished, Available, Finished)
# +--------------------+--------------------+--------------------+--------+--------------------+--------------------+-------------------+------------+--------------------+--------------+--------------------+------------------+------------------+------------------+----------+
# |                name|            address1|            address2|address3|        borough_name|             website|os_addressbase_uprn|borough_code|      ward_2018_name|ward_2018_code|           longitude|          latitude|           easting|          northing|   runtime|
# +--------------------+--------------------+--------------------+--------+--------------------+--------------------+-------------------+------------+--------------------+--------------+--------------------+------------------+------------------+------------------+----------+
# |Troubadour Wemble...|         Fulton Road|                null|    null|                null|                null|               null|        null|                null|          null| -0.2817884536759514| 51.56085053698574| 518981.3968192088| 186168.5883621346|11/27/2022|
# |Assembly Rooms, S...|      138 Maple Road|            Surbiton|      NA|Kingston upon Thames|                  NA|          128012933|   E09000021|               Grove|     E05000408| -0.3084259634104032|51.396239372785324|517558.33868540253|167823.83715724957|11/27/2022|
# |George Wood Theatre | Goldsmith's College| University of Lo...|      NA|            Lewisham|                  NA|       100023000000|   E09000023|           New Cross|     E05000449|-0.03771247917133249| 51.47568861221421| 536149.2429007317|  177126.135651234|11/27/2022|
# |Greenwich & Lewis...|        The Tramshed| 51-53 Woolwich N...|      NA|           Greenwich|http://www.glypt....|       100023000000|   E09000011|  Woolwich Riverside|     E05000230|     0.0663930789412|51.490012927078496| 543331.8397495545| 178917.5325181157|11/27/2022|
# |  Piccadilly Theatre|        16 Denman St|                Soho|      NA| City of Westminster|https://www.picca...|       100023000000|   E09000033|            West End|     E05000649|-0.13698033213759486| 51.51156528850338| 529155.9161177657|180934.85208039073|11/27/2022|
# |Bacon's College T...|    Timber Pond Road|         Rotherhithe|      NA|           Southwark|                  NA|       200003000000|   E09000028|         Rotherhithe|     E05011112|-0.04386252398093959|51.502875561798646|   535641.52779856|180137.32080730412|11/27/2022|
# |   Courtyard Theatre|  40 Pitfield Street|                  NA|      NA|             Hackney|                  NA|        10091002509|   E09000012|         Hoxton West|     E05009378|-0.08496288918437335| 51.52838974209928| 532715.5464827259|182898.55251109053|11/27/2022|
# +--------------------+--------------------+--------------------+--------+--------------------+--------------------+-------------------+------------+--------------------+--------------+--------------------+------------------+------------------+------------------+----------+
# only showing top 20 rows

# %% [markdown]
# Other commands available:
# * `%describe df`
# * %%add_comments
# * %%fix_errors
# * %pin df
# * %new_task

# %%
# %describe spark_df
# Out:
# It seems you have successfully loaded the CSV into the Spark DataFrame. Now you can perform operations on the `spark_df` DataFrame.
#
# Here it is to ensure you've got the DataFrame ready for further operations:
#
# ```python
# # Display the schema of the Spark DataFrame
# spark_df.printSchema()
#
# # Display some rows of the DataFrame
# spark_df.show()
#
# # Show basic statistics
# spark_df.describe().show()
# ```
#
# These commands will help you verify the structure and some basic statistics of the DataFrame. Let me know if you need any specific analysis or operations to be performed on this DataFrame.

# %% [markdown]
# Let's look at a little demo.  I have a file of `London theaters` and we can do analytics against it.
#
#
# [London Cultural Infrastructure Map](https://data.london.gov.uk/dataset/cultural-infrastructure-map)
# [Direct link to theaters.csv](https://data.london.gov.uk/download/cultural-infrastructure-map/c9bda99b-2156-4ecd-b09d-c207ae5947e2/Theatres.csv)
#
# You will need to download the csv file and upload it somewhere to your lakehouse.
#
# **Click the copilot option to "load my data from my lakehouse into a dataframe"** and type `Load Theatres.csv into a DataFrame`

# %%
# try the next option:
# Check the first few rows of the DataFrame using the head() function.
# ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

display(spark_df)
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 25, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 47c6b173-a191-4b40-b83f-1c4aa97ddd12)

# %%
# you should get some other interesting options to aid in Exploratory
# Data Analytics (EDA)

# calculate summary statistics for numerical columns
spark_df.describe()
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 26, Finished, Available, Finished)
# DataFrame[summary: string, name: string, address1: string, address2: string, address3: string, borough_name: string, website: string, os_addressbase_uprn: string, borough_code: string, ward_2018_name: string, ward_2018_code: string, longitude: string, latitude: string, easting: string, northing: string, runtime: string]

# %% [markdown]
# Let's try something more advanced.
#
# Try this:
#
# `Analyze Theatres.csv and provide me with insights about the data`
#
# ...but...we can use the data already in the Spark context, so instead of doing this in the chat window...do it in a new call with a chat magic.

# %%
# %%code
#
# Analyze the spark_df dataframe and tell me some insights about the data.
# Out:
# **chat-magics** generated the following cell.  Tokens: 114
#
# Remember that AI can make mistakes, so carefully review code before executing.

# %%
#### ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

# Display the schema of the Spark DataFrame
spark_df.printSchema()

# Show first few rows of the dataframe
spark_df.show()

# Summary statistics for numerical columns
spark_df.describe().show()

# Count the number of rows in the dataframe
row_count = spark_df.count()
print(f"Number of rows: {row_count}")

# Count the number of distinct values in 'borough_name' column
distinct_boroughs = spark_df.select('borough_name').distinct().count()
print(f"Number of distinct borough names: {distinct_boroughs}")

# Group by 'borough_name' and count occurrences
borough_count = spark_df.groupBy('borough_name').count()
borough_count.show()

# Show the distribution of mean runtime
#spark_df.groupBy().mean('runtime').show()

# Show the distribution of mean latitude and longitude
#spark_df.groupBy().mean('latitude', 'longitude').show()
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 30, Finished, Available, Finished)
# root
#  |-- name: string (nullable = true)
#  |-- address1: string (nullable = true)
#  |-- address2: string (nullable = true)
#  |-- address3: string (nullable = true)
#  |-- borough_name: string (nullable = true)
#  |-- website: string (nullable = true)
#  |-
+--------------------+--------------------+---------------+---------------+--------------------+--------------------+--------------------+------------+------------------+--------------+--------------------+--------------------+------------------+------------------+----------+
#
# Number of rows: 264
# Number of distinct borough names: 33
# +--------------------+-----+
# |        borough_name|count|
# +--------------------+-----+
# |          Wandsworth|    7|
# |             Croydon|    3|
# |              Bexley|    4|
# |             Lambeth|   18|
# | City of Westminster|   52|
# |Barking and Dagenham|    1|
# |              Camden|   24|
# |           Greenwich|    3|
# |                null|    1|
# |              Newham|    4|
# |       Tower Hamlets|    7|
# |              Barnet|    3|
# |            Hounslow|    6|
# |              Harrow|    2|
# |Kensington and Ch...|    9|
# |           Islington|   15|
# |               Brent|    1|
# |            Haringey|    8|
# |             Bromley|    4|
# |              Merton|    6|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# If we instead used `%%chat` instead of `%%code` it would have more explanatory text and the generated code cell would not be present.
#
# That's it!

# %%
# %%code
# Which ward has the most theaters (a ward is defined as the column called ward_2018_name?
# print that value.
# What is the mean?
# What is the standard deviation?
# Can you plot those?
# Out:
# **chat-magics** generated the following cell.  Tokens: 156
#
# Remember that AI can make mistakes, so carefully review code before executing.

# %%
import matplotlib.pyplot as plt

# Count the number of theaters in each ward
ward_theater_counts = result['ward_2018_name'].value_counts()

# Find the ward with the most theaters
ward_with_most_theaters = ward_theater_counts.idxmax()

# Calculate the mean and standard deviation of theater counts
mean_theater_count = ward_theater_counts.mean()
std_theater_count = ward_theater_counts.std()

# Plot the theater counts by ward
plt.figure(figsize=(12, 6))
ward_theater_counts.plot(kind='bar')
plt.title('Number of Theaters by Ward')
plt.xlabel('Ward')
plt.ylabel('Number of Theaters')
plt.show()

ward_with_most_theaters, mean_theater_count, std_theater_count
# Out:
# StatementMeta(, 8e0ba606-1439-4de7-bb46-8599202f5b31, 36, Finished, Available)
# ("St. James's", 1.777027027027027, 2.762284733992049)

# %%
# %%code
# Can you make this a normal distribution?
# Out:
# **chat-magics** generated the following cell.  Tokens: 75
#
# Remember that AI can make mistakes, so carefully review code before executing.

# %%
df["English"] = df["transcript"].ai.translate("english")

df.ai.classify("blah","blahblah")
# Out:
# StatementMeta(, 98aebb95-70d2-4ff8-8cbb-861ac356071a, 32, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 df["English"] = df["transcript"].ai.translate("english")
#       3 df.ai.classify("blah","blahblah")
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:2930, in DataFrame.__getitem__(self, item)
#    2858 """Returns the column as a :class:`Column`.
#    2859
#    2860 .. versionadded:: 1.3.0
#    (...)
#    2927 +---+----+
#    2928 """
#    2929 if isinstance(item, str):
# -> 2930     jc = self._jdf.apply(item)
#    2931     return Column(jc)
#    2932 elif isinstance(item, Column):
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/errors/exceptions/captured.py:175, in capture_sql_exception.<locals>.deco(*a, **kw)
#     171 converted = convert_exception(e.java_exception)
#     172 if not isinstance(converted, UnknownException):
#     173     # Hide where the exception came from that shows a non-Pythonic
#     174     # JVM exception message.
# --> 175     raise converted from None
#     176 else:
#     177     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `transcript` cannot be resolved. Did you mean one of the following? [`name`, `address1`, `address2`, `address3`, `borough_name`, `website`, `os_addressbase_uprn`, `borough_code`, `ward_2018_name`, `ward_2018_code`, `longitude`, `latitude`, `easting`, `northing`, `runtime`].
